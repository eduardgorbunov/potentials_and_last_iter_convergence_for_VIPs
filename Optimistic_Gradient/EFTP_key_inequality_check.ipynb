# %%
import numpy as np
from numpy.linalg import norm
import pickle
import matplotlib.pyplot as plt
import copy
import math
import time
import scipy
from pathlib import Path
import scipy.io
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # EFTP: analysis of $(N+1)\|F(x^N)\|^2 - 10\sum\limits_{k=0}^N \left(2\langle F(\widetilde{x}^{k-1}), F(\widetilde{x}^{k}) \rangle - \|F(\widetilde{x}^{k})\|^2\right)$

# %% [markdown]
# ## $L = 1, \mu = 0$

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True: #((i%2 == 1) and (j == i-1) and (j != 0)): #or ((i%2 == 0) and (j == i-2) and (j != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True: #((i%2 == 0) and (j == 0)) or ((i%2 == 1) and (j == i-2) and (j != 0)) or ((i == 3) and (j == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/gamma, annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[-3.067461e-13]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True: #((i%2 == 1) and (j == i-1) and (j != 0)): #or ((i%2 == 0) and (j == i-2) and (j != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True: #((i%2 == 0) and (j == 0)) or ((i%2 == 1) and (j == i-2) and (j != 0)) or ((i == 3) and (j == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/gamma, annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[1.30627675e-12]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True: #((i%2 == 1) and (j == i-1) and (j != 0)): #or ((i%2 == 0) and (j == i-2) and (j != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True: #((i%2 == 0) and (j == 0)) or ((i%2 == 1) and (j == i-2) and (j != 0)) or ((i == 3) and (j == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/gamma, annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[1.74948659e-12]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 30
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True: #((i%2 == 1) and (j == i-1) and (j != 0)): #or ((i%2 == 0) and (j == i-2) and (j != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True: #((i%2 == 0) and (j == 0)) or ((i%2 == 1) and (j == i-2) and (j != 0)) or ((i == 3) and (j == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (25,25))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/gamma, annot=True)

# %%
fig, ax = plt.subplots(figsize = (25,25))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[-6.56608346e-13]])

# %% [markdown]
# # EFTP: analysis of $(N+1)\|F(\widetilde{x}^N)\|^2 - 10\sum\limits_{k=0}^N \|F(\widetilde{x}^{k})\|^2$

# %% [markdown]
# ## $L = 1, \mu = 0$

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True:
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True:
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*(N_max+10)), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/(N_max+10), annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[3.9222654e-13]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True:
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True:
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*(N_max+10)), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/(N_max+10), annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[7.03118886e-13]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True: #((i%2 == 1) and (j == i-1) and (j != 0)): #or ((i%2 == 0) and (j == i-2) and (j != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True:
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*(N_max+10)), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/(N_max+10), annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[-5.67746646e-13]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 30
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True:
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True:
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix[-20:,-20:]*1.0/(gamma*(N_max+10)), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix[-20:,-20:]*1.0/(N_max+10), annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[-7.76444922e-14]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 70
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if True:
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if True:
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix[-30:,-30:]*1.0/(gamma*(N_max+10)), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix[-30:,-30:]*1.0/(N_max+10), annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[-4.3847533e-12]])

# %% [markdown]
# # EFTP: analysis of $2\|F(\widetilde{x}^N)\|^2 - \|F(\widetilde{x}^{N-1})\|^2 - 2\langle F(\widetilde{x}^{N-1}), F(\widetilde{x}^{N}) \rangle$

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_idea_4_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+3):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 == 0) and (j%2 == 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i == 2*N_max+2) and (j%2 == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_idea_4_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+3):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 == 0) and (j%2 == 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i == 2*N_max+2) and (j%2 == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_idea_4_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+3, 2*N_max+3))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+3):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 == 0) and (j%2 == 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i == 2*N_max+2) and (j%2 == 0)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %% [markdown]
# # EFTP: analysis of $(N+1)\|F(\widetilde{x}^N)\|^2 - 10\sum\limits_{k=0}^N \left(2\langle F(\widetilde{x}^{k-1}), F(\widetilde{x}^{k}) \rangle - \|F(\widetilde{x}^{k})\|^2\right)$

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 25
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix, annot=True)

# %% [markdown]
# # EFTP: analysis of $(N+1)\|F(\widetilde{x}^N)\|^2 - 10\sum\limits_{k=0}^N \|F(\widetilde{x}^{k})\|^2$

# %% [markdown]
# ## $\gamma = \frac{1}{2L}$

# %%
L = 1.0
gamma = 1.0/(2*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[6.39743563e-13]])

# %%
L = 1.0
gamma = 1.0/(2*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[8.34053609e-12]])

# %%
L = 1.0
gamma = 1.0/(2*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[8.7948315e-09]])

# %%
L = 1.0
gamma = 1.0/(2*L)
N_max = 25
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[1.48174655e-11]])

# %% [markdown]
# ## $\gamma = \frac{1}{4L}$

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[2.65912933e-12]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[5.466532e-09]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[5.94287347e-09]])

# %%
L = 1.0
gamma = 1.0/(4*L)
N_max = 25
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[2.22417947e-08]])

# %% [markdown]
# ## $\gamma = \frac{1}{8L}$

# %%
L = 1.0
gamma = 1.0/(8*L)
N_max = 10
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[1.19112912e-12]])

# %%
L = 1.0
gamma = 1.0/(8*L)
N_max = 15
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[5.21393885e-09]])

# %%
L = 1.0
gamma = 1.0/(8*L)
N_max = 20
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[6.75146332e-09]])

# %%
L = 1.0
gamma = 1.0/(8*L)
N_max = 25
gamma_str = '%.6f' % gamma

res_with_duals = scipy.io.loadmat('dump/EFTP_key_ineq_simple_tilde_dist_2_dual_variables_L_'+str(int(L))+'_N_'+str(N_max)+'__'+gamma_str+'.mat')
monotonicity_weights = np.round_(np.array(res_with_duals['monotonicity_weights'][0]), decimals=6)
Lipschitzness_weights = np.round_(np.array(res_with_duals['Lipschitzness_weights'][0]), decimals=6)
monotonicity_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0
Lipschitzness_weights_matrix = np.zeros((2*N_max+2, 2*N_max+2))*1.0



idx1 = 0
idx2 = 0
for i in np.arange(1, 2*N_max+2):
    for j in np.arange(0, i):
        if (i!=j) and (i!=2) and (i-j <= 2) and (j!=0):
            if ((i%2 != 1) or (j%2 != 1)) and ((i%2 != 0) or (j%2 != 0)):
                Lipschitzness_weights_matrix[i][j] = Lipschitzness_weights[idx1]
                idx1 += 1
            if ((i%2 == 1) and (j%2 == 1)):
                monotonicity_weights_matrix[i][j] = monotonicity_weights[idx2]
                idx2 += 1

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(monotonicity_weights_matrix*1.0/(gamma*Lipschitzness_weights_matrix[8][7]), annot=True)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax = sns.heatmap(Lipschitzness_weights_matrix*1.0/Lipschitzness_weights_matrix[8][7], annot=True)

# %%
res_with_duals['res_norm']
# Out:
# array([[1.18389376e-08]])
